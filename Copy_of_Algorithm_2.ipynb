# %%
# !pip3 install supabase
# Out:
# Collecting supabase
#   Downloading supabase-0.7.1-py3-none-any.whl (10 kB)
# Collecting postgrest-py<0.11.0,>=0.10.2
#   Downloading postgrest_py-0.10.3-py3-none-any.whl (15 kB)
# Collecting realtime<0.0.6,>=0.0.5
#   Downloading realtime-0.0.5-py3-none-any.whl (8.0 kB)
# Collecting gotrue<0.6.0,>=0.5.0
#   Downloading gotrue-0.5.4-py3-none-any.whl (24 kB)
# Collecting python-semantic-release==7.32.1
#   Downloading python_semantic_release-7.32.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 1.8 MB/s eta 0:00:00
# Collecting supafunc<0.3.0,>=0.2.2
#   Downloading supafunc-0.2.2-py3-none-any.whl (2.8 kB)
# Collecting httpx<0.24.0,>=0.23.0
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 1.2 MB/s eta 0:00:0072.3 MB/s eta 0:00:01
# Collecting storage3<0.4.0,>=0.3.5
#   Downloading storage3-0.3.5-py3-none-any.whl (12 kB)
# Requirement already satisfied: click<9,>=7 in /usr/local/lib/python3.10/site-packages (from python-semantic-release==7.32.1->supabase) (8.1.3)
# Collecting click-log<1,>=0.3
#   Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Collecting dotty-dict<2,>=1.3.0
#   Downloading dotty_dict-1.3.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: requests<3,>=2.25 in /usr/local/lib/python3.10/site-packages (from python-semantic-release==7.32.1->supabase) (2.28.1)
# Collecting tomlkit~=0.10
#   Downloading tomlkit-0.11.6-py3-none-any.whl (35 kB)
# Collecting invoke<2,>=1.4.1
#   Downloading invoke-1.7.3-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 6.2 MB/s eta 0:00:00
# Collecting twine<4,>=3
#   Downloading twine-3.8.0-py3-none-any.whl (36 kB)
# Collecting python-gitlab<4,>=2
#   Downloading python_gitlab-3.11.0-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 1.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/braden/Library/Python/3.10/lib/python/site-packages (from python-semantic-release==7.32.1->supabase) (21.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/site-packages (from python-semantic-release==7.32.1->supabase) (0.37.1)
# Requirement already satisfied: gitpython<4,>=3.0.8 in /usr/local/lib/python3.10/site-packages (from python-semantic-release==7.32.1->supabase) (3.1.27)
# Requirement already satisfied: semver<3,>=2.10 in /usr/local/lib/python3.10/site-packages (from python-semantic-release==7.32.1->supabase) (2.13.0)
# Collecting pydantic<2.0.0,>=1.9.1
#   Downloading pydantic-1.10.2-cp310-cp310-macosx_10_9_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 5.9 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/site-packages (from httpx<0.24.0,>=0.23.0->supabase) (2022.9.14)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting deprecation<3.0.0,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /Users/braden/Library/Python/3.10/lib/python/site-packages (from realtime<0.0.6,>=0.0.5->supabase) (2.8.2)
# Collecting dataclasses<0.7,>=0.6
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.2.0 in /usr/local/lib/python3.10/site-packages (from realtime<0.0.6,>=0.0.5->supabase) (4.3.0)
# Collecting websockets<11.0,>=10.3
#   Downloading websockets-10.4-cp310-cp310-macosx_10_9_x86_64.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/site-packages (from gitpython<4,>=3.0.8->python-semantic-release==7.32.1->supabase) (4.0.9)
# Collecting anyio==3.*
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 5.9 MB/s eta 0:00:00
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/site-packages (from anyio==3.*->httpcore<0.16.0,>=0.15.0->httpx<0.24.0,>=0.23.0->supabase) (3.4)
# Requirement already satisfied: six>=1.5 in /Users/braden/Library/Python/3.10/lib/python/site-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<0.0.6,>=0.0.5->supabase) (1.16.0)
# Collecting requests-toolbelt>=0.9.1
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.25->python-semantic-release==7.32.1->supabase) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.25->python-semantic-release==7.32.1->supabase) (2.1.1)
# Collecting keyring>=15.1
#   Downloading keyring-23.11.0-py3-none-any.whl (36 kB)
# Collecting colorama>=0.4.3
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tqdm>=4.14 in /usr/local/lib/python3.10/site-packages (from twine<4,>=3->python-semantic-release==7.32.1->supabase) (4.64.1)
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Collecting readme-renderer>=21.0
#   Downloading readme_renderer-37.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.10/site-packages (from twine<4,>=3->python-semantic-release==7.32.1->supabase) (4.12.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/braden/Library/Python/3.10/lib/python/site-packages (from packaging->python-semantic-release==7.32.1->supabase) (3.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.0.8->python-semantic-release==7.32.1->supabase) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/site-packages (from importlib-metadata>=3.6->twine<4,>=3->python-semantic-release==7.32.1->supabase) (3.8.1)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Collecting docutils>=0.13.1
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 9.5 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: Pygments>=2.5.1 in /Users/braden/Library/Python/3.10/lib/python/site-packages (from readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.32.1->supabase) (2.13.0)
# Collecting bleach>=2.1.0
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/site-packages (from jaraco.classes->keyring>=15.1->twine<4,>=3->python-semantic-release==7.32.1->supabase) (8.14.0)
# Installing collected packages: webencodings, rfc3986, invoke, dataclasses, websockets, tomlkit, sniffio, pydantic, pkginfo, jaraco.classes, h11, dotty-dict, docutils, colorama, click-log, bleach, requests-toolbelt, realtime, readme-renderer, keyring, deprecation, anyio, twine, python-gitlab, httpcore, python-semantic-release, httpx, supafunc, storage3, postgrest-py, gotrue, supabase
# Successfully installed anyio-3.6.2 bleach-5.0.1 click-log-0.4.0 colorama-0.4.6 dataclasses-0.6 deprecation-2.1.0 docutils-0.19 dotty-dict-1.3.1 gotrue-0.5.4 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 invoke-1.7.3 jaraco.classes-3.2.3 keyring-23.11.0 pkginfo-1.8.3 postgrest-py-0.10.3 pydantic-1.10.2 python-gitlab-3.11.0 python-semantic-release-7.32.1 readme-renderer-37.3 realtime-0.0.5 requests-toolbelt-0.10.1 rfc3986-1.5.0 sniffio-1.3.0 storage3-0.3.5 supabase-0.7.1 supafunc-0.2.2 tomlkit-0.11.6 twine-3.8.0 webencodings-0.5.1 websockets-10.4
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
from supabase import create_client, Client

url: str = 'https://gfmcdqiayiitfofbxgme.supabase.co'
key: str = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImdmbWNkcWlheWlpdGZvZmJ4Z21lIiwicm9sZSI6ImFub24iLCJpYXQiOjE2NjQ4MjY4MTUsImV4cCI6MTk4MDQwMjgxNX0.BDz1XcqxCywfWGE9Xp19FVu0_865VGsujzsDd0Xru_w'
supabase: Client = create_client(url, key)

# %%
data = supabase.table("responses").select("*").execute()
data = data.json()

# %%
import json
import pandas as pd

# Cleasing, parse string to json
data = json.loads(data)

# Load data into a DataFrame
df = pd.DataFrame(data['data'])
df
# Out:
#                            timestamp  year                year_match pronouns  \
# 0   2022-11-11T15:15:25.120379+00:00  2023                    [2023]  she/her
# 1    2022-11-11T16:02:03.41443+00:00  2024        [2025, 2024, 2023]  she/her
# 2    2022-11-11T16:03:51.37548+00:00  2026                    [2026]   he/him
# 3   2022-11-11T16:55:46.497251+00:00  2025                    [2025]  she/her
# 4   2022-11-11T17:45:16.801776+00:00  2026  [2026, 2025, 2024, 2023]   he/him
# ..                               ...   ...                       ...      ...
# 64  2022-11-13T19:49:25.169705+00:00  2023        [2025, 2024, 2023]   he/him
# 65  2022-11-13T20:03:13.754115+00:00  2025        [2025, 2024, 2023]   he/him
# 66  2022-11-13T20:08:55.924645+00:00  2025              [2025, 2024]  she/her
# 67  2022-11-13T20:14:37.376797+00:00  2026                    [2026]   he/him
# 68  2022-11-13T20:22:06.481186+00:00  2024              [2025, 2024]   he/him
#
#    pronouns_match       phone   nickname                        email  \
# 0             any  8184778416        Mar   mariam.alaverdian@yale.edu
# 1             any  4753016759        Tim     thimali.bandara@yale.edu
# 2       different  4752540906      Drew     Andrew.alam-nist@yale.edu
# 3            same  6103932933      Carol          carol.azar@yale.edu
# 4       different  9787701575  john wick        arnav.bhakta@yale.edu
# ..            ...         ...        ...                          ...
# 64            any  4802079206        mel  melquisedec.lozano@yale.edu
# 65            any  4753124082      Panda          aranyo.ray@yale.edu
# 66            any  5129985154        Liz         liz.frausto@yale.edu
# 67      different  2039481478       Appa          Kyle.robik@yale.edu
# 68      different  3012567935        ehu             evan.hu@yale.edu
#
#                                              keywords  \
# 0   entrepreneurship, finance, detective shows, th...
# 1
# 2   Art, philosophy, running, writing, adventurous...
# 3   enjoy weightlifting, am reliable and consisten...
# 4   wrestling, food, running, programming, entrepr...
# ..                                                ...
# 64  music, rollerblading, band, exercising, musica...
# 65  art, poetry, consulting, math, psychology, pos...
# 66  funny, kind, good listener, catholic, loves mu...
# 67  mf doom, kendrick Lamar, biochemistry, rock cl...
# 68  hip-hop, kpop, r&b, classical music, sports, f...
#
#                                        keywords_match  id    confirm
# 0    curious, finance, enterprenuership, comedy shows  19  [1, 2, 3]
# 1                                                      20  [1, 2, 3]
# 2                   Outgoing, energetic, adventurous   21  [1, 2, 3]
# 3   enjoys going to the gym, is honest and a relia...  22  [1, 2, 3]
# 4   wrestling, food, running, programming, entrepr...  23  [1, 2, 3]
# ..                                                ...  ..        ...
# 64  music, rollerblading, band, exercising, musica...  84  [1, 2, 3]
# 65           curious, consulting, kind, art, creative  85  [1, 2, 3]
# 66  Creative, hard-working, optimistic, good conve...  86  [1, 2, 3]
# 67                            cool, funny, passionate  87  [1, 2, 3]
# 68                                                     88  [1, 2, 3]
#
# [69 rows x 12 columns]
